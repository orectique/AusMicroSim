# %%
import pandasdmx as sdmx

# %%
req = sdmx.Request('ABS_XML')

# %%
metadata = req.datastructure()
# Out:
# 2023-08-10 23:56:35,329 pandasdmx.reader.sdmxml - DEBUG: Truncate sub-microsecond time in <Prepared>

# %%
metadata
# Out:
# <pandasdmx.StructureMessage>
#   <Header>
#     id: 'IDREF102442'
#     prepared: '2023-08-10T23:56:35.017776+10:00'
#     receiver: <Agency Unknown>
#     sender: <Agency Unknown>
#     source:
#     test: False
#   response: <Response [200]>
#   Codelist (480): CL_POP_PROJ CL_SEX CL_AGE CL_REMOTENESS CL_DEMOG_PROJ...
#   ConceptScheme (49): CS_COMMON CS_ACLD CS_C16_PERSON CS_C16_COMMON CS_...
#   DataStructureDefinition (1184): ABORIGINAL_POP_PROJ ABORIGINAL_POP_PR...

# %%
metadata.concept_scheme
# Out:
# {'CS_COMMON': <ConceptScheme ABS:CS_COMMON(1.0.0) (5 items)>,
#  'CS_ACLD': <ConceptScheme ABS:CS_ACLD(1.0.0) (8 items)>,
#  'CS_C16_PERSON': <ConceptScheme ABS:CS_C16_PERSON(1.0.0) (42 items)>,
#  'CS_C16_COMMON': <ConceptScheme ABS:CS_C16_COMMON(1.0.0) (9 items)>,
#  'CS_C16_FAMILY': <ConceptScheme ABS:CS_C16_FAMILY(1.0.0) (13 items)>,
#  'CS_C16_HOUSEHOLD': <ConceptScheme ABS:CS_C16_HOUSEHOLD(1.0.0) (15 items)>,
#  'CS_IT': <ConceptScheme ABS:CS_IT(1.0.0) (2 items)>,
#  'CS_INDUSTRY': <ConceptScheme ABS:CS_INDUSTRY(1.0.0) (1 items)>,
#  'CS_DECIMALS': <ConceptScheme ABS:CS_DECIMALS(1.0.0) (1 items)>,
#  'CS_LAND': <ConceptScheme ABS:CS_LAND(1.0.0) (8 items)>,
#  'CS_ITEM': <ConceptScheme ABS:CS_ITEM(1.0.0) (2 items)>,
#  'CS_INDEX': <ConceptScheme ABS:CS_INDEX(1.0.0) (2 items)>,
#  'CS_GEOGRAPHY': <ConceptScheme ABS:CS_GEOGRAPHY(1.0.0) (18 items)>,
#  'CS_SEIFA': <ConceptScheme ABS:CS_SEIFA(1.0.0) (2 items)>,
#  'CS_SU': <ConceptScheme ABS:CS_SU(1.0.0) (3 items)>,
# ...

# %%
flow = req.dataflow()
# Out:
# 2023-08-11 00:11:06,733 pandasdmx.reader.sdmxml - DEBUG: Truncate sub-microsecond time in <Prepared>

# %%
flow.dataflow
# Out:
# {'ABORIGINAL_POP_PROJ': <DataflowDefinition ABS:ABORIGINAL_POP_PROJ(1.0.0): Projected population, Aboriginal and Torres Strait Islander Australians, Australia, state and territories, 2016 to 2031>,
#  'ABORIGINAL_POP_PROJ_REMOTE': <DataflowDefinition ABS:ABORIGINAL_POP_PROJ_REMOTE(1.0.0): Projected population, Aboriginal and Torres Strait Islander Australians, Remotness Area, 2016 to 2031>,
#  'ABS_ABORIGINAL_POPPROJ_INDREGION': <DataflowDefinition ABS:ABS_ABORIGINAL_POPPROJ_INDREGION(1.0.0): Projected population, Aboriginal and Torres Strait Islander Australians, Indigenous Regions, 2016 to 2031>,
#  'ABS_ACLD_LFSTATUS': <DataflowDefinition ABS:ABS_ACLD_LFSTATUS(1.0.0): Australian Census Longitudinal Dataset (ACLD): Labour force status, 2006-2011>,
#  'ABS_ACLD_TENURE': <DataflowDefinition ABS:ABS_ACLD_TENURE(1.0.0): Australian Census Longitudinal Dataset (ACLD): Tenure and landlord type, 2006-2011>,
# ...

# %%
c21poa = flow.dataflow.C21_G01_POA

# %%
d = c21poa.structure

# %%
d.attributes.components
# Out:
# []
